# %% [markdown]
# Nested if-else

# %%
# if condition1:
      #outer if block
      #if condition two
         # innner if block
      #else:
         #inner else block
# else:
   #outer else block

# %%
num = int(input("Enter a  number:"))

if num>=0:
  if num == 0:
    print("the number is zero")
  else:
    print("The number is positive")
else:
  print("the number is negative")
# Out:
# Enter a  number:-5
# the number is negative

# %% [markdown]
# Multiple levels of nesting:

# %%
#three layers of nesting
score = 85
attendance =90
submitted= True


if score >=60:
  if attendance >=80:
    if submitted :
      print("pass with good standing")
    else:
      print("pass but missing assignment")
  else:
    print("pass but low attendance")
else:
  print("fail")
# Out:
# pass with good standing

# %% [markdown]
# Nested if vs Logical operators

# %%
temperature = 25
is_sunny= True

if temperature > 20:
  if is_sunny:
    print("Nice weather")
# Out:
# Nice weather

# %%
temperature= 25
is_sunny=True

if temperature > 20 and is_sunny:
  print("Nice weather")
# Out:
# Nice weather

# %%
username= "emily"
password ="python1234"
is_active= True

if username:
  if password:
    if is_active:
      print("login successful")
    else:
      print("account is not active")
  else:
    print("Account is not active")
else:
  print("username required")
# Out:
# login successful

# %%
score = 79
extra_credit = 5

if score>=90:
  if extra_credit>0:
    print ("A+ grade")
  else:
    print("A grade")
elif score >= 80:
  print("B grade")
else:
  print("C grade or below")
# Out:
# C grade or below

# %% [markdown]
# 1. A company is shortlisting candidates for hiring. The minimum requirement is at least 2 years of experience. If the candidate has passed the skill test and has 5 or more years of experience, they will be selected as a Senior, otherwise they will be selected as a Junior. If the candidate has failed the skill test, they will be Rejected. Regardless of these rules, if the background check fails, the final decision is always Rejected. Task: For a candidate with experience_years = 6, skill = "pass", and background_check = "pass", determine the final decision using nested if–else statements.

# %% [markdown]
# 2. Ask for the units of electricity consumed. If the units are 200 or more, print "Surcharge Applied". Within this, if the units are 500 or more, print "Heavy Surcharge". Otherwise, if the units are less than 200, print "No Surcharge".

# %% [markdown]
# 3. Ask for the speed of a car. If the speed is greater than 60, the driver must pay a fine. Within this case, if the speed is greater than 100, the fine is "Heavy Fine". If the speed is 60 or below, print "No Fine".

# %% [markdown]
# 4. Ask for withdrawal amount and balance. If the withdrawal amount is less than or equal to balance, print "Transaction Allowed". Within this case, if the withdrawal amount is more than 20000, print "Extra Verification Needed". Otherwise, if the amount is greater than balance, print "Insufficient Balance".

# %% [markdown]
# 5. A student is considered for a scholarship if their score is at least 85. If the score is 95 or above, they get 100% scholarship. If the score is 90 or above but less than 95, they get 50%. If the score is 85 or above but less than 90, they get 25%. Task: Ask student for score, compute the scholarship percentage using nested if–else statements.
