# %% [markdown]
# ## **18 Jan. 2026**

# %% [markdown]
# https://assets.openstax.org/oscms-prodcms/media/documents/Introduction_to_Python_Programming_-_WEB.pdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Variables**

# %%
x = 3
type(x)
# Out:
# int

# %%
x1 = 3.0
type(x1)
# Out:
# float

# %%
x2 = '3'
type(x2)
# Out:
# str

# %%
s = int(3)
type(s)
# Out:
# int

# %%
s1 = float(3)
type(s1)
# Out:
# float

# %%
s2 = str(3)
type(s2)
# Out:
# str

# %%
a = 3

# %%
type(a)
# Out:
# int

# %%
m1 = float(a)   # typecasting integer-a to float-m1
type(m1)
# Out:
# float

# %%
m2 = str(a)    # typecasting integer-a to string-m2
type(m2)
# Out:
# str

# %%
a = 5
b = 7

print("old a : ", a)

a = a + b   # first perform 5+7, then store the result (12) in a

print("new a : ", a)
# Out:
# old a :  5
# new a :  12

# %%
a = 5
b = 7

c = a   # c = 5
a = b   # a = 7
b = c   # b = 5

print(a, b)

# outcome:
# a = 7
# b = 5
# swapping using 3rd or temporary variable
# Out:
# 7 5

# %%
a = 5
b = 7
print(a, b)


a = a+b  # a = 5+7 = 12
b = a-b  # b = 12-7 = 5
a = a-b  # a = 12-5 = 7

print(a, b)
#swapping 2 no.s without using 3rd variable
# Out:
# 5 7
# 7 5

# %%
a = 5
b = 7

print(a,b)

(a, b) = (b, a)

print(a,b)
# Out:
# 5 7
# 7 5

# %%
a = 3
t = str(a)
type(t)
# Out:
# str

# %%
a = '3'
t = int(a)
type(t)
# Out:
# int

# %%
a = 'hello'
t = int(a)  # we can typecast only typecastable values stored in a variable
type(t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2261208931.py in <cell line: 0>()
#       1 a = 'hello'
# ----> 2 t = int(a)
#       3 type(t)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
a = 'h'
t = int(a)
type(t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4061303979.py in <cell line: 0>()
#       1 a = 'h'
# ----> 2 t = int(a)
#       3 type(t)
#
# ValueError: invalid literal for int() with base 10: 'h'

# %%
type(3.0)
# Out:
# float

# %%
f = str(3.0)
type(f)
# Out:
# str

# %%
print(f)
# Out:
# 3.0

# %%
f = int(3.0)
type(f)
# Out:
# int

# %%
print(f)
# Out:
# 3

# %%
a = '3'
t = float(a)
type(t)
# Out:
# float

# %%
print(t)
# Out:
# 3.0

# %%
z1 = 1j
z2 = 2j
print(z1+z2)
# Out:
# 3j

# %%
type(z1)
# Out:
# complex

# %%
z1 = 1 + 1j
z2 = 5 + 2j
print(z1+z2)
# Out:
# (6+3j)

# %%
z1 = 1 + 1j
z2 =     2j     # 0 + 2j
print(z1+z2)
# Out:
# (1+3j)

# %%
z1 = 1 + 1j
z2 = .2 + 2j
print(z1+z2)
# Out:
# (1.2+3j)

# %%
x = 1
c = complex(x)
type(c)
# Out:
# complex

# %%
print(c)
# Out:
# (1+0j)

# %%
c1 = 1j  # 0 + 1j
x1 = int(c1)
type(x1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2344501992.py in <cell line: 0>()
#       1 c1 = 1j
# ----> 2 x1 = int(c1)
#       3 type(x1)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
c1 = complex(1)  # 1 + 0j
x1 = int(c1)
type(x1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-49432497.py in <cell line: 0>()
#       1 c1 = complex(1)  # 1 + 0j
# ----> 2 x1 = int(c1)
#       3 type(x1)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
print(c1)
# Out:
# (1+0j)

# %%
print('hello')
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %%
print('hello")
# Out:
#   File "/tmp/ipython-input-2736789527.py", line 1
#     print('hello")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello')
# Out:
#   File "/tmp/ipython-input-1040585027.py", line 1
#     print("hello')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello! Welcome to Python class")
# Out:
# hello! Welcome to Python class

# %%
print("hello! Welcome to 'Python' class")
# Out:
# hello! Welcome to 'Python' class

# %%
print("hello! Welcome to "Python" class")
# Out:
#   File "/tmp/ipython-input-4156505082.py", line 1
#     print("hello! Welcome to "Python" class")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('hello! Welcome to "Python" class')
# Out:
# hello! Welcome to "Python" class

# %%
print("It's okay")
# Out:
# It's okay

# %%
print("""
A
B
C
""")
# Out:
# A
# B
# C

# %%
s = "abcde"
print(s)
# Out:
# abcde

# %%
print(s[0])
# Out:
# a

# %%
print(s[0], s[1], s[2], s[3], s[4])
# Out:
# a b c d e

# %%
print(s[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1602430366.py in <cell line: 0>()
# ----> 1 print(s[5])
#
# IndexError: string index out of range

# %%
len(s)
# Out:
# 5

# %%
s1 = "ab cde"
print(s1)
# Out:
# ab cde

# %%
len(s1)
# Out:
# 6

# %%
print(s1[2])

# %%
s = "abcde"

print(s[0 : 3])  # s[0], s[1], s[2]

# 0 1 2 3 4
# a b c d e
# Out:
# abc

# %%
print(s[0:2])
# Out:
# ab

# %%
print(s[0:1])
# Out:
# a

# %%
print(s[0 : ]) # same as    print(s[0 : len(s) ])
# Out:
# abcde

# %%
# 0 1 2 3 4
# a b c d e
print(s[0 : 5 ])
# Out:
# abcde

# %%
len(s)
# Out:
# 5

# %%
print(s[0 : len(s) ])
# Out:
# abcde

# %%
print(s[0],s[1],s[2])  # side by side printing
# Out:
# a b c

# %%
print(s[0]+s[1]+s[2]) # string concatenation
# Out:
# abc

# %%
# 0 1 2 3 4
# a b c d e
print(s[0 : 3])
# Out:
# abc

# %%
print(s[ : 3])  # same as    print(s[0 : 3])
# Out:
# abc

# %%
print(s[1 : 3])
# Out:
# bc

# %%
# 0 1 2 3 4
# a b c d e

print(s[-1])
# Out:
# e

# %%
print(s[-5], s[-4], s[-3], s[-2], s[-1])
# Out:
# a b c d e

# %%
#  0    1    2    3    4
#  a    b    c    d    e
# -5   -4   -3   -2   -1

# %%
print(s[-3 : -1])
# Out:
# cd

# %%
print(s[ : -1])
# Out:
# abcd

# %%
print(s[-5 : -1])
# Out:
# abcd

# %%
#  0    1    2    3    4
#  a    b    c    d    e
# -5   -4   -3   -2   -1
print(s[-3 : ])
# Out:
# cde

# %%
print(s[0 : -1])
# Out:
# abcd

# %%
print(s[1 : -1])
# Out:
# bcd

# %%
print(s[-3 : len(s) ])
# Out:
# cde

# %%
print(s[-3 : 0 ])

# %%
#  0    1    2    3    4
#  a    b    c    d    e
# -5   -4   -3   -2   -1
print(s[-3 : -5 ])

# %%
print(s[0 : 5 ])
# Out:
# abcde

# %%
print(s[0 : 5 : 1])
# Out:
# abcde

# %%
print(s[0 : 5 : 2])
# Out:
# ace

# %%
print(s[-5 : -3 ])
# Out:
# ab

# %%
LHS = -5
RHS = 3
print(s[LHS : RHS ])
# Out:
# abc

# %%
a = 'hi'
print(a.upper())
# Out:
# HI

# %%
a = 'HI'
print(a.lower())
# Out:
# hi

# %%
print( (a.upper()).lower() )
# Out:
# hi

# %%
a= 'chandra'
len(a)
# Out:
# 7

# %%
a= '  chandra   '
len(a)
# Out:
# 12

# %%
b = a.strip()
len(b)
# Out:
# 7

# %%
b
# Out:
# 'chandra'

# %%
a
# Out:
# '  chandra   '

# %%
a = 'hi'
b = a.replace('h', 'x')

print(a, b)
# Out:
# hi xi

# %%
s = 'hello, world'
s1 = s.split(', ')

# %%
s1[0]
# Out:
# 'hello'

# %%
s1[1]
# Out:
# 'world'

# %%
s1
# Out:
# ['hello', 'world']

# %%
s
# Out:
# 'hello, world'

# %%
a = 'hello'
b = 'world'
c = a+b  # string concatenation, concating 2 strings
print(c)
# Out:
# helloworld

# %%
a = 'hello'
b = 'world'
c = a+" "+b  # concating 3 strings
print(c)
# Out:
# hello world

# %%
print(a+b) #string concatenation
# Out:
# helloworld

# %%
print(a,b) # not string concatnation, printing side-by-side
# Out:
# hello world

# %%
s = "7+5+9"
s1 = s.split("+")

# %%
print(s)
# Out:
# 7+5+9

# %%
print(s1)
# Out:
# ['7', '5', '9']

# %%
print(s1[0], s1[1], s1[2])
# Out:
# 7 5 9

# %%
print(s1[0] + s1[1] + s1[2])
# Out:
# 759

# %%
type(s1[0])
# Out:
# str

# %%
print(int(s1[0]) + int(s1[1]) + int(s1[2]))
# Out:
# 21

# %%
age = 35
s = "chandra's age is " + age
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1734860048.py in <cell line: 0>()
#       1 age = 35
# ----> 2 s = "chandra's age is " + age
#       3 print(s)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 35
s = "chandra's age is " + str(age)
print(s)
# Out:
# chandra's age is 35

# %%
# f-string

age = 35
s = f"chandra's age is {age}"  # {} are used as placeholder for variables
print(s)
# Out:
# chandra's age is 35

# %%
price = 50
s = f"rice cost is {price:.2f}"
print(s)
# Out:
# rice cost is 50.00

# %%
price = 50
s = f"2 kg rice cost is {price * 2}"
print(s)
# Out:
# 2 kg rice cost is 100

# %%
pi = 3.1428
s = f"pi value is {pi:.2f}"
print(s)
# Out:
# pi value is 3.14

# %%
score = 92.45678
s10 = f"Score: {score:>8.2f} | Status: {'PASS':^10}"
print(s10)
# Out:
# Score:    92.46 | Status:    PASS

# %%
name = 'AI'
s = f"{name:*^10}"
print(s)

# outcome: 10 character length
# fill character: *
# ^ Center alignment
# Out:
# ****AI****

# %%
name = 'AI'
s = f"{name:+^10}"
print(s)
# Out:
# ++++AI++++

# %%
name = 'AI'
s = f"{name:*>10}"
print(s)
# > right alignment
# Out:
# ********AI

# %%
name = 'AI'
s = f"{name:*<10}"
print(s)
# < left alignment
# Out:
# AI********

# %%
score = 92.45678
s10 = f"{'PASS':.^10}"
print(s10)
# Out:
# ...PASS...

# %%
len(s10)
# Out:
# 10

# %%
score = 92.45678
s10 = f"Score: {score:>8.2f} | Status: {'PASS':^10}"
print(s10)

# width = minimum 8 character, after decimal point 2 digits
# Out:
# Score: ***92.46 | Status:    PASS

# %%
score = 12345092.45678
s10 = f"Score: {score:>8.2f} | Status: {'PASS':^10}"
print(s10)
# Out:
# Score: 12345092.46 | Status:    PASS

# %%
marks = [78, 85, 92]
len(marks)
avg = sum(marks)/len(marks)
print(avg)
print(max(marks))
# Out:
# 85.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1402777726.py in <cell line: 0>()
#       3 avg = sum(marks)/len(marks)
#       4 print(avg)
# ----> 5 print(max(marks))
#
# TypeError: 'list' object is not callable

# %%
marks = [78, 85, 92]
s = f"Max:{max(marks):>5} Avg:{sum(marks)/len(marks):.2f}"
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3318169595.py in <cell line: 0>()
#       1 marks = [78, 85, 92]
# ----> 2 s = f"Max:{max(marks):>5} Avg:{sum(marks)/len(marks):.2f}"
#       3 print(s)
#
# TypeError: 'list' object is not callable

# %%
x = -45.6

s = f"Result:{x:=10.2f}"

print(s)
# Out:
# Result:-    45.60

# %%
x = -45.6

s = f"Result:{x:*=10.2f}"

print(s)
# Out:
# Result:-****45.60

# %%
x = -45.6

s = f"Result:{x:.2f}"

print(s)
# Out:
# Result:-45.60

# %%
x = -45.6

s = f"Result:{x:=.2f}"   # = is for sign-aware padding

print(s)
# Out:
# Result:-45.60

# %%
x = -45.6

s = f"Result:{x:>10.2f}"   # = is for sign-aware padding

print(s)
# Out:
# Result:    -45.60

# %%
x = -45.6

s = f"Result:{x:=10.2f}"   # = is for sign-aware padding

print(s)

# (vertically aligned)
# Out:
# Result:-    45.60

# %%
pi = 3.1428
s = f"pi value is {pi:.2f}"
print(s)
# Out:
# pi value is 3.14

# %% [markdown]
# ## **25 Jan. 2026**

# %%
x1 = '5'
x2 = '6'
print(x1+x2)
# Out:
# 56

# %%
print(int(x1) + int(x2))
# Out:
# 11

# %%
print(int(x1) + (x2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1530612303.py in <cell line: 0>()
# ----> 1 print(int(x1) + (x2))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 10   # int
b = 3    # int
c = a/b  # float

# %%
print(type(a), type(b), type(c))
# Out:
# <class 'int'> <class 'int'> <class 'float'>

# %%
c
# Out:
# 3.3333333333333335

# %%
a1 = 9   # int
b1 = 3    # int
c1 = a1/b1  # ?

# %%
type(c1)
# Out:
# float

# %%
c1
# Out:
# 3.0

# %%
c2 = int(a/b)
print(c2)
# Out:
# 3

# %%
cc1 = 2j         # complex, having imaginary part only
cc2 = 1 + 3j
cc3 = cc1 + cc2
print(cc3)
# Out:
# (1+5j)

# %%
type(cc1)
# Out:
# complex

# %%
cc1 = 2           # int, having the real part
cc2 = 1 + 3j
cc3 = cc1 + cc2
print(cc3)
# Out:
# (3+3j)

# %%
type(cc1)
# Out:
# int

# %%
a = 5
A = 7

print(a, A) # variable names are case-sensitive
# Out:
# 5 7

# %%
a = 1

a = a + 1   #   a <-- 1+1   ; a_new = a_old (1) + 1

print(a)  # a_new
# Out:
# 2

# %%
a = 5
a = 6  # now a value has been over-written to 6
print(a, a)
# Out:
# 6 6

# %% [markdown]
# Legal variable names

# %%
iitpatna = 5

# %%
iit_patna = 5

# %%
_iit_patna = 5

# %%
_iit_patna_ = 5

# %%
iitpatna1 = 5

# %%
iit1patna = 5

# %%
IITPatna = 5

# %%
iit______patna = 5

# %% [markdown]
# IIlegal variable names (not allowed)

# %%
1iitpatna = 5 # not allowed
# Out:
#   File "/tmp/ipython-input-2280303531.py", line 1
#     1iitpatna = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
iit-patna = 5
# Out:
#   File "/tmp/ipython-input-793676191.py", line 1
#     iit-patna = 5
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
iit patna = 5
# Out:
#   File "/tmp/ipython-input-4042808492.py", line 1
#     iit patna = 5
#         ^
# SyntaxError: invalid syntax

# %%
a = 1
print(id(a))
a = a + 1
print(id(a))

# id is a unique integer that identifies the object during its lifetime
# id() as the object's address
# Out:
# 11654376
# 11654408

# %%
11654408 - 11654376
# Out:
# 32

# %%
a = 1
print(id(a))
a = a + 1
print(id(a))
a = a + 1
print(id(a))
# Out:
# 11654376
# 11654408
# 11654440

# %%
11654440 - 11654408
# Out:
# 32

# %%
b = 1.0
print(id(b))
b = b + 1.0
print(id(b))
b = b + 1.0
print(id(b))
# Out:
# 136201528619312
# 136201528607664
# 136201528607312

# %%
136201528607664 - 136201528619312
# Out:
# -11648

# %%
136201528607312 - 136201528607664
# Out:
# -352

# %%
type(b)
# Out:
# float

# %%
x = 10
y = 10
print(id(x), id(y))   # id(x), id(y) both are referring the same object
# Out:
# 11654664 11654664

# %%
type(x)
# Out:
# int

# %%
id(x) - id(y)
# Out:
# 0

# %%
a = [10, 20, 30]
b = [10, 20, 30]
print(id(a), id(b)) # a and b are different objects, even though values are equal
# Out:
# 136201527823936 136201527834880

# %%
type(a)
# Out:
# list

# %%
print (a==b) # values are equal
# Out:
# True

# %%
print (a is b) # objects are different
# Out:
# False

# %%
print(x is y)
# Out:
# True

# %%
# == : value equality
# is : same object
# id() : object identity

# %%
print(hex(id(a))) # hexadecimal form
# Out:
# 0x7bdfe3af0e40

# %%
import ctypes
a = 1

# %%
addr = id(a)
val1 = ctypes.cast(addr, ctypes.py_object).value

print("id(a): ", addr  ,   ";   value at id(a)", val1)
# Out:
# id(a):  11654376 ;   value at id(a) 1

# %%
a = 1
print(id(a))

a = 1
print(id(a))
# Out:
# 11654376
# 11654376

# %%
a = 1
print(id(a))

a = a+1
print(id(a))
# Out:
# 11654376
# 11654408

# %%
a = 1
print(id(a))

a = 2
print(id(a))
# Out:
# 11654376
# 11654408

# %%
a = 5
b = 6

(a,b) = (b,a)

print(a,b)
# Out:
# 6 5

# %%
a = 5
b = 6

(a,b) = (b,a)

print(b,a)
# Out:
# 5 6

# %%
a, b = 5, 6

print(a,b)
# Out:
# 5 6

# %%
a1, a2, a3, a4 = 90, 93, 85, 89

# %%
print(a3)
# Out:
# 85

# %%
a5 = a6 = a7 = 80

# %%
print(a6)
# Out:
# 80

# %%
marks = [90, 93, 85, 89]

# %%
a1, a2, a3, a4 = marks

# %%
print(a1)
# Out:
# 90

# %%
print(marks[0])
# Out:
# 90

# %%
print(marks[0], marks[1], marks[2], marks[3])
# Out:
# 90 93 85 89

# %%
name = ['ram', 'rahim', 'john', 'jain']
print(name[1])
# Out:
# rahim

# %%
print(name[0], name[1], name[2], name[3])
# Out:
# ram rahim john jain

# %%
print(name[0], marks[0])
# Out:
# ram 90

# %%
a = 'hello'
print(a[0])
# Out:
# h

# %%
type(a)
# Out:
# str

# %%
type(a[0])
# Out:
# str

# %%
print(a[4])
# Out:
# o

# %%
len(a)
# Out:
# 5

# %%
print(a[ len(a)-1 ])
# Out:
# o

# %%
print(a[0], a[1], a[2], a[3], a[4] )
# Out:
# h e l l o

# %%
for i in a: print(i)  # looping in a string. Here i works as a iterator
# Out:
# h
# e
# l
# l
# o

# %%
for i in a:
  print(i)    # be very careful about indentation in Python
# Out:
# h
# e
# l
# l
# o

# %%
for i in a:
print(i)
# Out:
#   File "/tmp/ipython-input-3931568851.py", line 2
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
import random
print(random.randrange(1,10))  #generate a random no. within the range of 1 to 10
# Out:
# 1

# %%
print(random.randrange(1,2)) # check whether 2 is inclusive !
# Out:
# 1

# %%
str1 = "Welcome to IIT Patna"
print('IIT' in str1)            #finding string IIT
# Out:
# True

# %%
str1 = "Welcome to IIT Patna"
print('iit' in str1)             #case-sensitive
# Out:
# False

# %%
name = ['ram', 'rahim', 'john', 'jain']
print('ram' in name)
# Out:
# True

# %%
str1 = "Welcome to IIT Patna"
key1 = 'iit'
print(key1 in str1)
# Out:
# False

# %%
str1 = "Welcome to IIT Patna"
key1 = 'iiT'
print(key1.lower() in str1.lower())
# Out:
# True

# %%
x = bool(10)
print(x)
# Out:
# True

# %%
x = bool(-10)
print(x)
# Out:
# True

# %%
x = bool(0)
print(x)
# Out:
# False

# %% [markdown]
# Quiz:
#
#
# Only for Zero-value (or None), bool() returns False

# %%
x = bool(0.5)
print(x)
# Out:
# True

# %%
type(x)
# Out:
# bool

# %%
x = None
print(x, type(x))
# Out:
# None <class 'NoneType'>

# %%
x1 = bool(x)
print(x1)
# Out:
# False

# %%
x =1j
x2 = bool(x)
print(x2)
# Out:
# True

# %%
x = bool(1/0)
print(x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2725375268.py in <cell line: 0>()
# ----> 1 x = bool(1/0)
#       2 print(x)
#
# ZeroDivisionError: division by zero

# %%
y =1/0
print(y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-1349333490.py in <cell line: 0>()
# ----> 1 y =1/0
#       2 print(y)
#
# ZeroDivisionError: division by zero

# %%
x = bool(False)
print(x)
# Out:
# False

# %%
x = False
print(x, type(x))
# Out:
# False <class 'bool'>

# %%
y = int(3)
type(y)
# Out:
# int

# %%
y = bool(3)
type(y)
# Out:
# bool

# %%
y
# Out:
# True

# %%
n = '012345'

# %%
print(n[0:4])
# Out:
# 0123

# %%
print(n[:4])
# Out:
# 0123

# %%
print(n[0:])
# Out:
# 012345

# %%
n = '012345'
print(n[0], n[5], n[-1], n[-2], n[-6])
# Out:
# 0 5 5 4 0

# %%
print(n[-6: -1])

# %%
print(n[-6: -2])

# %%
print(n[ : -1])

# %%
print(n[-6: ])

# %%
s1 = "iit patna"
s2 = s1.split(' ')
print(s2)
# Out:
# ['iit', 'patna']

# %%
len(s1)
# Out:
# 9

# %%
s2[0]
# Out:
# 'iit'

# %%
s2[1]
# Out:
# 'patna'

# %%
print(len(s2[0]), len(s2[1]))
# Out:
# 3 5

# %%
type(s2[0])
# Out:
# str

# %%
print(s2[0],s2[1])
# Out:
# iit patna

# %%
print(s2[0] + s2[1])
# Out:
# iitpatna

# %%
print(s2[0])
# Out:
# iit

# %%
print(s2[0][0])
# Out:
# i

# %%
print(s2[0][0], s2[0][2], s2[1][0], s2[1][1])   # i    t    p   a

# s2[0] : iit
# s2[1] : patna
# Out:
# i t p a

# %%
a = 'hi'
b = 'hello'
print(a,b)
print(a+b)
print(a+' '+b)
print(a+''+b)    #just gave 2 single inverted comma without any space
# Out:
# hi hello
# hihello
# hi hello
# hihello

# %%
print(a+b)
print(a +b)
print(a+ b)
# Out:
# hihello
# hihello
# hihello

# %%
print(a+''+b)     # no space
print(a+' '+b)     # 1 space
print(a+'  '+b)     # 2 spaces
# Out:
# hihello
# hi hello
# hi  hello

# %%
print(a+'\n'+b) # new line
# Out:
# hi
# hello

# %%
print(a+'\t'+b) # tab
# Out:
# hi	hello

# %%
print(a+'\\'+b)
# Out:
# hi\hello

# %%
print(a+'\'+b)
# Out:
#   File "/tmp/ipython-input-596763886.py", line 1
#     print(a+'\'+b)
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
c = 'hi\hello'
print(c)
# Out:
# hi\hello
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# /tmp/ipython-input-3004063806.py:1: SyntaxWarning: invalid escape sequence '\h'
#   c = 'hi\hello'

# %%
c = 'hi\thello'
print(c)
# Out:
# hi	hello

# %%
c = 'hi\nhello'
print(c)
# Out:
# hi
# hello

# %%
c = 'hi\n\thello'
print(c)
# Out:
# hi
# 	hello

# %%
c = 'hi\\hello'
print(c)
# Out:
# hi\hello

# %%
c = 'hi\bhello'
print(c)
# Out:
# hello

# %%
c = 'hi\"hello'
print(c)
# Out:
# hi"hello

# %%
c = 'hi\?hello'
print(c)
# Out:
# hi\?hello
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# /tmp/ipython-input-4174912795.py:1: SyntaxWarning: invalid escape sequence '\?'
#   c = 'hi\?hello'

# %%
c = 'hi\*hello'
print(c)
# Out:
# hi\*hello
# <>:1: SyntaxWarning: invalid escape sequence '\*'
# <>:1: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipython-input-727464589.py:1: SyntaxWarning: invalid escape sequence '\*'
#   c = 'hi\*hello'

# %%
str = "I love my India. india is a very beautiful country. Welcome to india"
x = str.count('india')
print(x)
# Out:
# 2

# %%
str = "I love my India. india is a very beautiful country. Welcome to india"
key = 'India'
x = str.count(key)
print(x)
# Out:
# 1

# %% [markdown]
# Homework: make it non-"case-sensitive"

# %% [markdown]
# https://en.wikipedia.org/wiki/Computer
#
#
# https://en.wikipedia.org/wiki/Flowchart

# %% [markdown]
# # **1 Feb. 2026**

# %%
str = "I love my India. india is a very beautiful country. Welcome to india"
key = 'india'
x = str.count(key)
print(x)
# Out:
# 2

# %%
str = "I love my India. india is a very beautiful country. Welcome to india"
key = 'India'
x = (str.lower()).count(key.lower())
print(x)
# Out:
# 3

# %%
str2 = str.lower()
str2
# Out:
# 'i love my india. india is a very beautiful country. welcome to india'

# %%
x2 = str2.capitalize() # 1st letter of the entire paragraph is in Caps
print(x2)
# Out:
# I love my india. india is a very beautiful country. welcome to india

# %%
str3 = str2.split('. ')
print(str3)
# Out:
# ['i love my india', 'india is a very beautiful country', 'welcome to india']

# %%
str3[0]
# Out:
# 'i love my india'

# %%
str3[0].capitalize()
# Out:
# 'I love my india'

# %%
str3[1].capitalize()
# Out:
# 'India is a very beautiful country'

# %%
str4 = str3[0].capitalize() + '. ' + str3[1].capitalize() + '. ' + str3[2].capitalize() + '.'
print(str4)
# Out:
# I love my india. India is a very beautiful country. Welcome to india.

# %%
# I love my india --> I love my India
s1 = "I love my india"
s2 = s1.split(' ')
print(s2)
# Out:
# ['I', 'love', 'my', 'india']

# %%
print(s2[0],s2[1],s2[2],s2[3].capitalize())
# Out:
# I love my India

# %%
s1.title()
# Out:
# 'I Love My India'

# %%
x1 = "India, officially the Republic of india. india is a country in South Asia. india is the seventh-largest country by area. india is the most populous country since 2023."

# %%
x2 = x1.replace('india', 'India')
x2
# Out:
# 'India, officially the Republic of India. India is a country in South Asia. India is the seventh-largest country by area. India is the most populous country since 2023.'

# %%
# later we will learn if-else, that time we will keep on checking and replace

# (InDia.lower()).replace

# %% [markdown]
# # **Basic arithmatic operator**

# %%
# +, -, *, /, %, **, //

# %%
a = 10
b = 3
c = a*b
print(c)
print(type(a), type(b), type(c))
# Out:
# 30
# <class 'int'> <class 'int'> <class 'int'>

# %%
a = 10
b = 3
c = a/b
print(c)
# Out:
# 3.3333333333333335

# %%
print(type(a), type(b), type(c))
# Out:
# <class 'int'> <class 'int'> <class 'float'>

# %%
c = int(a/b)
print(c, type(c))
# Out:
# 3 <class 'int'>

# %%
c1 = a//b   # floor division
print(c1, type(c1))
# Out:
# 3 <class 'int'>

# %%
c2 = a % b # modulus
print(c2, type(c2))
# Out:
# 1 <class 'int'>

# %%
c3 = a*b
print(c3, type(c3))
# Out:
# 30 <class 'int'>

# %%
c4 = a**b   #exponential
print(c4, type(c4))
# Out:
# 1000 <class 'int'>

# %%
c5 = 2**3
print(c5)
# Out:
# 8

# %%
a = 10
b = 3
c = a + b   # first calculate (a+b), then store the result in c
print(c)
# Out:
# 13

# %%
a = 10
b = 3
a = a + b   # first calculate (a+b), then store the result in a
print(a)
# Out:
# 13

# %%
a = 10
b = 3
print(a)
a = a + b   # first calculate (a+b), then store the result in a
print(a)
# Out:
# 10
# 13

# %%
a = 10
a = a + 3   # first calculate (a+3), then store the result in a
print(a)
# Out:
# 13

# %%
a = 10
a += 3   # a = a + 3
print(a)
# Out:
# 13

# %%
a = 10
b = 3
a += b   # a = a + b
print(a)
# Out:
# 13

# %%
a = 10
a *= 3   # a = a * 3
print(a)
# Out:
# 30

# %%
a = 10
a **= 3   # a = a ** 3
print(a)
# Out:
# 1000

# %%
print(x:=3)
# Out:
# 3

# %%
x
# Out:
# 3

# %%
x = 3
print(x)

# print(x:=3)
# Out:
# 3

# %%
print(x=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3142568202.py in <cell line: 0>()
# ----> 1 print(x=3)
#
# TypeError: 'x' is an invalid keyword argument for print()

# %%
x=3

# %%
print(x==3)  # check whether the value of x is 3
# Out:
# True

# %% [markdown]
# **Assignment operators:** = ,+=, -=, /=, %=, ...

# %% [markdown]
# **Bitwise operator:** &, ^, ~, >>, <<

# %%
print(3 & 5)  # bitwise AND
# Out:
# 1

# %%
print(3 | 5) # bitwise OR
# Out:
# 7

# %%
print(3 ^ 5) # bitwise XOR
# Out:
# 6

# %%
x1 = not(6)  # will see later
print(x1)
# Out:
# False

# %%
a = 3
print(~3)  # signed integer, 2's complement (self-study)
# Out:
# -4

# %%
print(10 << 2)  # binary shift-left 2 bits
# Out:
# 40

# %%
print(40 >> 2)  # binary shift-right 2 bits
# Out:
# 10

# %%
# swapping 2 no.s without using 3rd varibale and without using arithmatic operator

a = 10
b = 20
print(a,b)


a = a^b
b = a^b
a = a^b

print(a,b)
# Out:
# 10 20
# 20 10

# %% [markdown]
# # **Comparison operator**

# %%
# ==, >, <, >=, <=, !=

# %%
A = 10
B = 10

print(A==B)
# Out:
# True

# %%
print(A>B)
# Out:
# False

# %%
A = 9.9
B = 10

print(A<B)
# Out:
# True

# %%
A = 9.9
B = 10

print(A<=B)
# Out:
# True

# %%
print(A != B)
# Out:
# True

# %%
a = 2
b = 2
print( (a+b) == 4)
# Out:
# True

# %%
a = 1
b = 2
print( (a+b) == 3)
# Out:
# True

# %%
a = 0.2
b = 0.2
print( (a+b) == 0.4)
# Out:
# True

# %%
a = 0.1
b = 0.2
print( (a+b) == 0.3)
# Out:
# False

# %%
a = 40.5
b = 50.1
print( (a+b) == 90.6)
# Out:
# True

# %%
a = 0.1
b = 0.2
c = a+b
print( c == 0.3)
# Out:
# False

# %%
c

# floating point representation # IEEE-754 standarization for storing float
# careful on financial software, medical software, ...
# Out:
# 0.30000000000000004

# %%
a
# Out:
# 0.1

# %%
b
# Out:
# 0.2

# %%
a1 = 0.2
b1 = 0.2
c1 = a1+b1
print(c1)
print( c1 == 0.4)
# Out:
# 0.4
# True

# %%
a1 = 0.3
b1 = 0.3
c1 = a1+b1
print(c1)
print( c1 == 0.6)
# Out:
# 0.6
# True

# %%
# In floating point representation, you may face some issue

# %%
a = 0.1
b = 0.2
c = a+b
print( c == 0.3)
# Out:
# False

# %%
a = 0.1
b = 0.2
c = abs((a+b) - 0.3)
print( c < 1e-9)   # 10^(-9)
print(c)
# Out:
# True
# 5.551115123125783e-17

# %%
import math
print(math.isclose(a+b, 0.3))
# Out:
# True

# %%
from decimal import Decimal

a = Decimal('0.1')
b = Decimal('0.2')
print( (a + b) == Decimal('0.3'))
# Out:
# True

# %%
print(0.3 - 0.2)
# Out:
# 0.09999999999999998

# %%
print(0.2 - 0.1)
# Out:
# 0.1

# %%
print(  (0.3 - 0.2) == (0.2 - 0.1)   )
# Out:
# False

# %%
print(0.1 * 3)
print((0.1 * 3) == 0.3)
# Out:
# 0.30000000000000004
# False

# %%
1/10
# Out:
# 0.1

# %%
1.0/10
# Out:
# 0.1

# %%
print(  (1.0/10) == 0.1   )
# Out:
# True

# %%
print( round(2.675, 2)   )
# Out:
# 2.67

# %%
a = 2.675
print(a)    # 2.67499999999...
# Out:
# 2.675

# %%
print( round(2.677, 2)   )
# Out:
# 2.68

# %%
a
# Out:
# 2.675

# %%
print(format(a, '.50f')  )



# . precision indicator
# 50  no. of digits after the deciaml point
# f  fixed floating decimal notation
# Out:
# 2.67499999999999982236431605997495353221893310546875

# %%
print(format(a, '.0f')  )
print(format(a, '.2f')  )
print(format(a, '.5f')  )
print(format(a, '.55f')  )
# Out:
# 3
# 2.67
# 2.67500
# 2.6749999999999998223643160599749535322189331054687500000

# %%
x = 1234.56789
print(format(x,'.2e'))
# Out:
# 1.23e+03

# %%
1e2
# Out:
# 100.0

# %%
1.23e2
# Out:
# 123.0

# %%
x = 1234.56789
print(format(x,'.6g'))

x1 = 0.000012345
print(format(x1,'.6g'))  # formatting small numbers
# Out:
# 1234.57
# 1.2345e-05

# %%
x2 = 0.0000000000000000000000000000000012345
print(format(x2,'.6g'))    # it makes shorter in more meaningful way for understanding in human eye
# Out:
# 1.2345e-33

# %%
a = 12.34567
print(format(a,'.4f'))  # 4 digits after decimal
print(format(a,'.4g'))  # 4 significant digits
# Out:
# 12.3457
# 12.35

# %%
# f: currency, reports   --> fixed point, decimal places matter
# e : scientific data  --> exponential notation
# g : logging, debugging, ---> adaptive, significant digits

# %%
print(0.0000000000000000000000000000000012345)

# print() internally uses g-like behaviour
# Out:
# 1.2345e-33

# %% [markdown]
# ## **8 Feb. 2026**

# %% [markdown]
# # **Operators**
#
# *   Arithmatic (+, - , /, *, ...)
# *   Assignment (=, +=, -=, ...)
# *   Comparison (==, !=, >, ...)
# *   Bitwise (&, |, ^, <<, >>, ...)
# *   Logical (and, or, not)
# *   Membership (in, not in)
# *   Identity (is, is not)

# %%
a = 0.1
b = 0.2
c = 0.2
print( (a+b) == 0.3)
print( (b+c) == 0.4)

print( repr(a+b) )
print( repr(b+c) )

#repr
# storing 64-bit binary representation
# built-in function to show what is actually stored in memory
# (in this case, showing exact floating point representation stored in memory, it is showing the precise internal value)
# Out:
# False
# True
# 0.30000000000000004
# 0.4

# %%
s = 'hi'
print(s)
print(repr(s))
# Out:
# hi
# 'hi'

# %%
a = True
b = False
print(a and b)
# Out:
# False

# %%
print(a && b)
# Out:
#   File "/tmp/ipython-input-1513217463.py", line 1
#     print(a && b)
#              ^
# SyntaxError: invalid syntax

# %%
print(a or b)
# Out:
# True

# %%
print(not b)
# Out:
# True

# %%
x = 5
y = 10
print(x>y)
# Out:
# False

# %%
print(x < 6  and y < 11)  # comparison op. , logical op.
# Out:
# True

# %%
print( not(x>y) )
# Out:
# True

# %%
s = ("hello word, welcome to india")

# %%
key = "india"
print(key in s)
# Out:
# True

# %%
key = "India"
print(key not in s)
# Out:
# True

# %%
x = 5
y = 5
print(x==y)
# Out:
# True

# %%
print(x is y)
# Out:
# True

# %%
print(x is not y)
# Out:
# False

# %% [markdown]
# # **Operator Precedence**
# (self-study)

# %%
print(6+3-2)
# Out:
# 7

# %%
print(6-3*2) # 0 or 6
# Out:
# 0

# %%
print( (6-3) * 2)
# Out:
# 6

# %%
print(100 - 20 - 50)  # 80 - 50  = 30 (left to right associative)          #  100 - 70 = 30
# Out:
# 30

# %%
print(100 / 2 / 50)    # left to right assoc.
# Out:
# 1.0

# %%
print( 2 ** 3 ** 2 )   # 8^2 = 64  (left to right assoc.)    #  2^9 = 512 (right to left assoc.)

# right to left
# Out:
# 512

# %%
print(2 + 3 * 4 ** 2)
# Out:
# 50

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Homework: check the above pictures with examples

# %% [markdown]
# # **Conditions**

# %%
a = 6
b = 5

if (a>b): # True
  print('a is greater than b')
# Out:
# a is greater than b

# %%
a = 6
b = 5

if (a>b):
print('a is greater than b')
# Out:
#   File "/tmp/ipython-input-753964896.py", line 5
#     print('a is greater than b')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
a = 6
b = 5

if (a>b): print('a is greater than b')
# Out:
# a is greater than b

# %%
a = 6
b = 5

if (a>b): # TRUE
  print('a is greater than b')
else:     # FALSE
  print('b is greater than a')
# Out:
# a is greater than b

# %%
a = 6
b = 51

if (a>b):
  print('a is max')
else:
  print('b is max')
# Out:
# b is max

# %%
a = 6
b = 6

if (a>b):
  print('a is max')
elif (a==b):
  print('a is equal to b')
else:
  print('b is max')
# Out:
# a is equal to b

# %%
a = 6
b = 6

if a>b:
  print('a is max')
elif a==b:
  print('a is equal to b')
else:
  print('b is max')
# Out:
# a is equal to b

# %%
a = 6
b = 6

if a>b: print('a is max')
elif a==b: print('a is equal to b')
else: print('b is max')
# Out:
# a is equal to b

# %%
a = 6

if a==6:
  print('hi')
  print('hello')
# Out:
# hi
# hello

# %%
a = 6

if a==6: print('hi') print('hello')
# Out:
#   File "/tmp/ipython-input-2895052778.py", line 3
#     if a==6: print('hi') print('hello')
#                          ^
# SyntaxError: invalid syntax

# %%
a = 6

if a==6:
  print('hi') # inside if block
print('hello') # outside if
# Out:
# hi
# hello

# %%
a = 6

if a==6: print('hi')
print('hello') # outside if
# Out:
# hi
# hello

# %% [markdown]
# max among 3 no.s

# %%
a = 10
b = 20
c = 3

if (a>b) and (a>c):
  print('a is max')
if (b>a) and (b>c):
  print('b is max')
if (c>a) and (c>b):
  print('c is max')
# Out:
# b is max

# %% [markdown]
# Find max among 3 no.s using NESTED IF-ELSE

# %%
a= 100
b = 20
c = 300

if a>b:
  if a>c: print('a is max')
  else: print('c is max')    # c>a>b
else:
  if b>c: print('b is max')  # b>a and b>c
  else: print('c is max')    # b>a and c>b
# Out:
# c is max

# %%
a = 1
b = 2
if not a>b:
  print('b is max')
# Out:
# b is max

# %%
a = 1
b = 2
if a!=b:
  print('a is not equal to b')
# Out:
# a is not equal to b

# %% [markdown]
# ==, !=, <, >, <=, >=

# %%
a = 11
b = 2

if (a>b):
  print('a')
else:
  print('b')
# Out:
# a

# %% [markdown]
# ternary operator

# %%
print('a') if a>b else print('b')   # ternary operator
# Out:
# a

# %%
a = 6
b = 6

if (a>b):
  print('a')
elif (a==b):
  print('a=b')
else:
  print('b')
# Out:
# a=b

# %%
a = 6
b = 6

if (a>b):
  print('a')
else:
  if (a==b):
    print('a=b')
  else:
    print('b')
# Out:
# a=b

# %%
print('a') if a>b    else      print('a=b') if a==b else print('b')  # ternary operator
# Out:
# a=b

# %%
if (a>b): print('a')
else:
  if (a==b): print('a=b')
  else: print('b')
# Out:
# a=b

# %%
print('a') if a>b else print('a=b') if a==b else print('b')  # ternary operator

# %%
a = 1
b =2
c =3
if a>b or c>b: # false or true
  print('hi')
# Out:
# hi

# %%
x = 5
if x>10:
else: print('Hi')
# Out:
#   File "/tmp/ipython-input-1758778536.py", line 3
#     else: print('Hi')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
n= 5
if n%2 == 0: print('even')
else: print('odd')
# Out:
# odd

# %% [markdown]
# Homework:
# *   Electricity bill calculator
# *   FD interest calculator
# *   Insurance policy premium calculator
# *   Simple income tax calculator

# %% [markdown]
# 1.   Straigh-forward (rule-book)
# 2.   Coding variations (understand others code)
# 3.   Tricky question (test your skill)

# %%
if []:              # empty list
  print("True")
else:
  print("False")
# Out:
# False

# %%
a = 0
if a:
  print("True")
else:
  print("False")
# Out:
# False

# %%
a = -1
if a:
  print("True")
else:
  print("False")
# Out:
# True

# %%
a = 0.1
if a:
  print("True")
else:
  print("False")
# Out:
# True

# %%
a = 1
if a:
  print("True")
else:
  print("False")
# Out:
# True

# %%
a = 5
b = 5
c = 5
if a == b == c:
  print("All equal")
# Out:
# All equal

# %%
a = 5
b = 5
c = 5
if (a == b) and (b == c):
  print("All equal")
# Out:
# All equal

# %%
x = 1
y = [2, 3]

if x in y == False:
  print("yes")
else:
  print("No")
# Out:
# No

# %%
if x in y and y == False:
  print("yes")
else:
  print("No")
# Out:
# No

# %%
x = 1
y = [2, 3]

if x not in y:
  print("yes")
else:
  print("No")
# Out:
# yes

# %%
a = 256
b = 256

if a is b:
  print("Same object")
else:
  print("Different object")
# Out:
# Same object

# %%
a = 256
b = 256

if a == b:
  print("Same object")
else:
  print("Different object")
# Out:
# Same object

# %%
a = 257
b = 257

print(a == b)
print(a is b)
# Out:
# True
# False

# %%
if False:
  print('A')
  print('B')
else:
  print('C')
# Out:
# C

# %%
if False:
  print('A')
print('B')  # outside of the if block
# Out:
# B

# %%
if (n := 5 ) > 3:
  print(n)
# Out:
# 5

# %%
print(n:=5)   # := walrus operator
# Out:
# 5

# %%
# floating point trap

if 0.1 + 0.2 == 0.3:
  print("Equal")
else:
  print("Not Equal")

# due to floating point precision
# Out:
# Not Equal

# %%
import math


if math.isclose(0.1+0.2, 0.3):
  print("Equal")
else:
  print("Not Equal")
# Out:
# Equal

# %%
if :   # space
  print("True")
else:
  print("False")
# Out:
#   File "/tmp/ipython-input-2959347516.py", line 1
#     if :
#        ^
# SyntaxError: invalid syntax

# %%
if " ":             # string with an empty space : not empty
  print("True")
else:
  print("False")
# Out:
# True

# %%
if "":             # empty string
  print("True")
else:
  print("False")
# Out:
# False

# %%
if True:print("hi")
# Out:
# hi

# %%
if True;print("hi")
# Out:
#   File "/tmp/ipython-input-2687050901.py", line 1
#     if True;print("hi")
#            ^
# SyntaxError: invalid syntax

# %%
if True:print("hi");
# Out:
# hi

# %%
x = 10

if x > 5:        # true
  if x > 15:     # false
    print("Big")
else:
  print("Small")

# chained if-else return confusion

# %%
x = 10

if x > 5:        # true
  if x > 15:     # false
    print("Big")
  else:
    print('medium')
else:
  print("Small")
# Out:
# medium

# %%
x = 5
result = 'Odd' if x%2 ==0 else "Even"
print(result)
# Out:
# Even

# %%
x = 5
result = 'Even' if x%2 ==0 else "Odd"
print(result)
# Out:
# Odd

# %%
if True == False:
  print("Impossible")
else:
  print("Possible")
# Out:
# Possible

# %%
x = 0

if x > 0:     # false
  print("Positive")
elif x > -1:   # true
  print ("non Negative")
else:
  print("Negative")


# elif is checked only if the previous if is FALSE
# Out:
# non Negative

# %%
x = 0

if x > -1.5:     # true
  print("Positive")
elif x > -1:
  print ("non Negative")
else:
  print("Negative")


# elif is checked only if the previous if is FALSE
# Out:
# Positive

# %%
if True + True + False:   # 1 + 1 + 0
  print("Yes")
else:
  print("No")
# Out:
# Yes

# %%
x = 0    # false
y = 10   # true

if x or y:  #true or false --> true
  print(x or y)   # getting true value
# Out:
# 10

# %%
print(0 or 10)
# Out:
# 10

# %%
print(0 or 0)
# Out:
# 0

# %%
print(None or "Hello")
# Out:
# Hello

# %%
x = 5
if x>10 and x>2:   # false and
  print("World")
else:
  print("Hello")
# Out:
# Hello

# %%
x = 5
if x>10 and print("Hello"):
  print("World")

# %%
x = 5
if print("Hello") and x>10:
  print("World")
# Out:
# Hello
